# %% [markdown]
# Evaluator

# %%
from dotenv import load_dotenv
load_dotenv()
import os
from typing_extensions import Literal,TypedDict
from typing import Annotated,List
from pydantic import BaseModel,Field
from langchain_core.messages import HumanMessage,SystemMessage
from langgraph.graph import StateGraph
from typing_extensions import TypedDict
from langgraph.graph import START,END, StateGraph
from IPython.display import Image,display

#os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

from langchain_groq import ChatGroq
llm = ChatGroq(model = "llama-3.3-70b-versatile")    #"qwen/qwen3-32b")

result = llm.invoke("Hello")
result
# Out:
# AIMessage(content='Hello. How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 36, 'total_tokens': 46, 'completion_time': 0.041030988, 'completion_tokens_details': None, 'prompt_time': 0.001736546, 'prompt_tokens_details': None, 'queue_time': 0.059033573, 'total_time': 0.042767534}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019ba36a-0a52-7d90-a378-3fc558771592-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 10, 'total_tokens': 46})

# %%
class State(TypedDict):
    joke:str
    topic:str
    feedback:str
     
    funny_or_not:str

# %%
class Feedback(BaseModel):
    grade:Literal["funny","not funny"]=Filed(co)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 class Feedback(BaseModel):
#       2     grade:Literal["funny","not funny"]=Filed(co)
#
# Cell In[8], line 2, in Feedback()
#       1 class Feedback(BaseModel):
# ----> 2     grade:Literal["funny","not funny"]=Filed(co)
#
# NameError: name 'Filed' is not defined
